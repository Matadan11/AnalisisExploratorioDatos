# %% [markdown]
# # Análisis Exploratorio de Datos (EDA) - Bank Churners
#
# Este notebook documenta el proceso de análisis de un conjunto de datos de clientes bancarios para entender las características de aquellos que abandonan el servicio.

# %%
from Paquete_GuiaEDA import AnalisisDatosExploratorio

ruta = "BankChurners.csv"

eda = AnalisisDatosExploratorio(ruta, 1)

eda.analisisNumerico()   # opcional
eda.analisis()
# Out:
# Dimensiones: (810, 10)
#            Customer_Age  Dependent_count  Months_on_book  \
# ID
# 714073983            47                2              36
# 718076733            43                1              31
# 710511858            58                0              36
# 766273533            53                2              46
# 779249583            56                1              38
#
#            Total_Relationship_Count  Months_Inactive_12_mon  \
# ID
# 714073983                         6                       3
# 718076733                         4                       3
# 710511858                         3                       3
# 766273533                         3                       6
# 779249583                         4                       3
#
#            Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# ID
# 714073983                      3        7327.0                    0
# 718076733                      3       25824.0                 1170
# ...
